# %% [markdown]
# ## Chaper 1 - Getting & Knowing Your Data

# %%
import pandas as pd

# %%
order_details = pd.read_csv('data.tsv.txt',sep='\t' )
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### 1.1 Perform Initial Analysis Data

# %%
order_details.shape
# Out:
# (4622, 5)

# %%
order_details.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
order_details.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# ## 1.2 Find out the Items Sold in the Restaurent

# %%
order_details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(order_details['item_name'].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# ## 1.3 Give me Top 5 Selling Items

# %%
order_details.groupby(by='item_name')["quantity"].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# ## 1.3.1 Give me the list of Least 5 Selling Items

# %%
order_details.groupby(by='item_name')["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %% [markdown]
# ## Chapter 2 - Data Cleaning

# %%
order_details['item_price'] = order_details['item_price'].str.replace("$","").astype(float) #Chain of Methods

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ### Task 1 - Top 5 Selling Item individual Revenue it made

# %%
order_details.groupby(by="item_name")["item_price"].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Name: item_price, dtype: float64

# %% [markdown]
# ### Task 2 - Total Revenue of the Top 5 Items Sold

# %%
Total_Revenue_of_Top_5=order_details.groupby(by="item_name")["item_price"].sum().sort_values(ascending=False).head().sum()
print(Total_Revenue_of_Top_5)
# Out:
# 21231.21

# %% [markdown]
# ### Task 3 - Total Revenue Sold Items

# %%
Total_revenue_of_sold_items=order_details["item_price"].sum()
print(Total_revenue_of_sold_items)
# Out:
# 34500.16

# %% [markdown]
# ### Task 4 - Total Revenue of the Least 5 Items Sold

# %%
Least_5_items_total_revenue= order_details.groupby(by='item_name')['item_price'].sum().sort_values().head().sum()
print(Least_5_items_total_revenue)
# Out:
# 50.08

# %% [markdown]
# ## Chapter 3 - Pandas Data Structure

# %%
pd.Series(data=[1,2])
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
pd.DataFrame(data= {"Names" : ["Siva","Naveen","Ribash","Mani"],
                    "Maths" : [75,72,70,80],
                    "Science" : [83,82,80,90]})
# Out:
#     Names  Maths  Science
# 0    Siva     75       83
# 1  Naveen     72       82
# 2  Ribash     70       80
# 3    Mani     80       90

# %% [markdown]
# ### Task 1 - Create Meaningful Series

# %%
pd.Series(data=[91,79,75,93,98],index=["Tamil","English","Maths","Science","Social"],name= "This is Siva 10th Mark" )
# Out:
# Tamil      91
# English    79
# Maths      75
# Science    93
# Social     98
# Name: This is Siva 10th Mark, dtype: int64

# %% [markdown]
# ### Task 2 - Create Meaningful Dataset using pandas DataFrame with Dictionary

# %%
Marks=pd.DataFrame(data={"STANDARD" : ["SSLC","HSC-I","HSC-II"],
                  "TOTAL_MARKS" : [436,427,463]})
Marks
# Out:
#   STANDARD  TOTAL_MARKS
# 0     SSLC          436
# 1    HSC-I          427
# 2   HSC-II          463

# %% [markdown]
# ## Chapter 4 - Filtering, Selection & Sorting

# %%
Euro_2012_data = pd.read_csv('Euro_2012_stats_TEAM.csv')
Euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
Euro_2012_data.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
Filter_euro_data=Euro_2012_data[['Team','Goals','Yellow Cards', 'Red Cards']]
Filter_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
Filter_euro_data.sort_values(by='Yellow Cards', ascending=False)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 7                 Italy      6            16          0
# 10             Portugal      6            12          0
# 13                Spain     12            11          0
# 0               Croatia      4             9          0
# 6                Greece      5             9          1
# 14               Sweden      5             7          0
# 9                Poland      2             7          1
# 1        Czech Republic      4             7          0
# 12               Russia      5             6          0
# 11  Republic of Ireland      1             6          1
# 4                France      3             6          0
# 3               England      5             5          0
# 8           Netherlands      2             5          0
# 15              Ukraine      2             5          0
# 5               Germany     10             4          0
# 2               Denmark      4             4          0

# %% [markdown]
# ### Task 1 - Top 5 Yellow Cards Team

# %%
Filter_euro_data.sort_values(by='Yellow Cards',ascending=False).head()
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %% [markdown]
# ### Task 2 - Red Cards Team

# %%
Filter_euro_data[Filter_euro_data['Red Cards'] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %% [markdown]
# ### Task 3 - More than 8 Yellow Cards Team

# %%
Filter_euro_data[Filter_euro_data['Yellow Cards'] >= 8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# ### Task 4 - Total Goals

# %%
Total_Goals = Filter_euro_data['Goals'].sum()
print("Total_Goals:",Total_Goals)
# Out:
# Total_Goals: 76

# %% [markdown]
# ### Task 5 - Below 5 Yellow Cards Team

# %%
Least_Yellow_Cards_Teams = Filter_euro_data[Filter_euro_data["Yellow Cards"] < 5]
Least_Yellow_Cards_Teams
# Out:
#       Team  Goals  Yellow Cards  Red Cards
# 2  Denmark      4             4          0
# 5  Germany     10             4          0

# %% [markdown]
# ### Task 6 - Zero Red Cards Teams

# %%
Filter_euro_data[Filter_euro_data['Red Cards'] == 0]
# Out:
#               Team  Goals  Yellow Cards  Red Cards
# 0          Croatia      4             9          0
# 1   Czech Republic      4             7          0
# 2          Denmark      4             4          0
# 3          England      5             5          0
# 4           France      3             6          0
# 5          Germany     10             4          0
# 7            Italy      6            16          0
# 8      Netherlands      2             5          0
# 10        Portugal      6            12          0
# 12          Russia      5             6          0
# 13           Spain     12            11          0
# 14          Sweden      5             7          0
# 15         Ukraine      2             5          0

# %% [markdown]
# ## Chapter 5 - How to Deal with Missing Data

# %%
import pandas as pd

# %%
employee_data = pd.read_csv('employee_data.csv')
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# # Level 1 of Data Cleaning

# %% [markdown]
# ### I'll call my client and get right data from him - Great!!
#
# Incase client is asking to perform the data cleaning operatins

# %% [markdown]
# #### Step 1 - Remove Duplicates

# %%
employee_data_updated = employee_data.drop_duplicates()
employee_data_updated
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# ### Step 2 - Find out the Null entries

# %%
employee_data_updated.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %%
employee_data_updated.dropna()
employee_data_updated
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data_updated.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# ### Step 3 - Record in  a Documents
#
# client gave totally 7 observations out of 3 observations are removed because of duplicates & null entries

# %% [markdown]
# ### Step 4 - Get Approval
#
# send this to my client and get approval to proceed for model building or training

# %%
employee_data_updated.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# # Level 2 of Data Cleaning

# %%
pip install openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
updated_emp_data=pd.read_excel("employee_data.xlsx",sheet_name = "More_employee_Data" )
updated_emp_data
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11        Mathiew   NaN    Support  58000.0 2025-01-15
# 12  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 13           Mani  28.0        Ops      NaN 2021-05-21

# %% [markdown]
# ## Step 1 - Drop duplicates

# %%
updated_emp_data.drop_duplicates(inplace=True)

# %%
updated_emp_data
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 13           Mani  28.0        Ops      NaN 2021-05-21

# %% [markdown]
# ## Step 2 - Identify Null Entries

# %%
updated_emp_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        5
# Join_Date     1
# dtype: int64

# %% [markdown]
# ## Step 3 - Go for best Imputation

# %%
updated_emp_data['Department'].unique()
# Out:
# array(['Ops', 'IT Tech', 'Support'], dtype=object)

# %%
updated_emp_data[updated_emp_data['Department'] == 'Support']
# Out:
#       Name   Age Department   Salary  Join_Date
# 2  Mathiew   NaN    Support  58000.0 2025-01-15
# 4    Kevin  28.0    Support  61000.0 2024-07-30
# 5    Navin  35.0    Support  72000.0 2023-08-19
# 9    Ajesh  28.0    Support      NaN 2024-07-30

# %%
ops=updated_emp_data[updated_emp_data['Department'] == 'Ops']
ops
# Out:
#          Name   Age Department   Salary  Join_Date
# 0      Rajesh  29.0        Ops  60000.0 2023-05-21
# 3     Gilbert  29.0        Ops  60000.0 2021-05-21
# 8   Kuppusamy  28.0        Ops      NaN 2021-05-21
# 13       Mani  28.0        Ops      NaN 2021-05-21

# %%
updated_emp_data[updated_emp_data['Department'] == 'IT Tech']
# Out:
#              Name   Age Department   Salary  Join_Date
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech      NaN        NaT

# %% [markdown]
# ### Task 1 - Impute relevant values in salary column in NaN based on Department

# %%
updated_emp_data.loc[(updated_emp_data['Department'] == 'Support') & (updated_emp_data['Salary'].isna()),'Salary'
] = 60000.0
updated_emp_data.loc[updated_emp_data['Name'] == 'Ajesh']
# Out:
#          Name   Age Department   Salary  Join_Date
# 0      Rajesh  29.0        Ops  60000.0 2023-05-21
# 3     Gilbert  29.0        Ops  60000.0 2021-05-21
# 8   Kuppusamy  28.0        Ops      NaN 2021-05-21
# 13       Mani  28.0        Ops      NaN 2021-05-21

# %%
updated_emp_data.loc[(updated_emp_data['Department'] == 'Ops') & (updated_emp_data['Salary'].isna()),'Salary'
] = 60000.0
updated_emp_data.loc[updated_emp_data['Name'] == ['Kuppusamy','Mani']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 3
#       1 updated_emp_data.loc[(updated_emp_data['Department'] == 'Ops') & (updated_emp_data['Salary'].isna()),'Salary'
#       2 ] = 60000.0
# ----> 3 updated_emp_data.loc[updated_emp_data['Name'] == ['Kuppusamy','Mani']]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
updated_emp_data[updated_emp_data['Department'] == 'Ops']
# Out:
#          Name   Age Department   Salary  Join_Date
# 0      Rajesh  29.0        Ops  60000.0 2023-05-21
# 3     Gilbert  29.0        Ops  60000.0 2021-05-21
# 8   Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 13       Mani  28.0        Ops  60000.0 2021-05-21

# %%
updated_emp_data
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 9           Ajesh  28.0    Support  60000.0 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 13           Mani  28.0        Ops  60000.0 2021-05-21

# %%
updated_emp_data[updated_emp_data['Department'] == 'IT Tech']
# Out:
#              Name   Age Department   Salary  Join_Date
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech      NaN        NaT

# %%
updated_emp_data.loc[(updated_emp_data['Department'] == 'IT Tech') & (updated_emp_data['Salary'].isna()),'Salary'
] = [62000.0,59000.0]
updated_emp_data.loc[updated_emp_data['Name'] == ['Roshan','Jagadheeswari']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 3
#       1 updated_emp_data.loc[(updated_emp_data['Department'] == 'IT Tech') & (updated_emp_data['Salary'].isna()),'Salary'
#       2 ] = [62000.0,59000.0]
# ----> 3 updated_emp_data.loc[updated_emp_data['Name'] == ['Roshan','Jagadheeswari']]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
updated_emp_data[updated_emp_data['Department'] == 'IT Tech']
# Out:
#              Name   Age Department   Salary  Join_Date
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech  62000.0 2020-11-12
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech  59000.0        NaT

# %%
updated_emp_data
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech  62000.0 2020-11-12
# 8       Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 9           Ajesh  28.0    Support  60000.0 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech  59000.0        NaT
# 13           Mani  28.0        Ops  60000.0 2021-05-21

# %% [markdown]
# ### Task 2 - Impute Mathiew age is 27

# %%
updated_emp_data.loc[updated_emp_data['Name'] == 'Mathiew', 'Age'] = 27
updated_emp_data
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathiew  27.0    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech  62000.0 2020-11-12
# 8       Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 9           Ajesh  28.0    Support  60000.0 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheeswari  28.0    IT Tech  59000.0        NaT
# 13           Mani  28.0        Ops  60000.0 2021-05-21
